# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('bjj-heroes-clean.csv')

print(df.sample())
# Out:
#           id               name        team        oppName outcome  \
# 12960  14957  Gabrieli Pessanha  Infight Jj  Ingridd Alves       W
#
#            method weightDiv  year
# 12960  Verbal Tap       ABS  2021

# %%
outcomes = df['outcome']

plt.bar(outcomes.unique(), df.value_counts(outcomes), )
plt.show()

print(df.value_counts(outcomes))
# Out:
# outcome
# W    31175
# L    12365
# D        1
# Name: count, dtype: int64
